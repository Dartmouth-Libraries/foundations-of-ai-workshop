# %% [markdown]
# # 🚀 Foundations of AI Workshop - Setup
#
# **Run this notebook first to ensure all dependencies are installed.**
#
# Simply click **Run All** (or run the cell below) to check your environment.

# %%
# Foundations of AI Workshop - Dependency Check & Installation

import sys
import subprocess
import importlib

print("🔍 Checking workshop dependencies...\n")

# Package mapping (import name : pip name)
packages = {
    'jupyter': 'jupyter>=1.0.0',
    'ipywidgets': 'ipywidgets>=8.0.0',
    'matplotlib': 'matplotlib>=3.5.0',
    'numpy': 'numpy>=1.21.0',
    'plotly': 'plotly>=5.0.0',
    'seaborn': 'seaborn>=0.11.0',
    'scipy': 'scipy>=1.7.0',
    'PIL': 'Pillow>=9.0.0',
    'torch': 'torch>=1.9.0',
    'sklearn': 'scikit-learn>=1.0.0',
    'IPython': 'ipython>=8.0.0'
}

to_install = []

# Check what needs installation
for import_name, pip_package in packages.items():
    try:
        importlib.import_module(import_name)
        print(f"✓ {import_name} already installed")
    except ImportError:
        print(f"✗ {import_name} needs installation")
        to_install.append(pip_package)

# Install missing packages
if to_install:
    print(f"\n📦 Installing {len(to_install)} missing packages...")
    try:
        subprocess.check_call([
            sys.executable, "-m", "pip", "install", "-q"
        ] + to_install)
        print("\n✅ Installation complete! Please restart the kernel.")
    except Exception as e:
        print(f"\n❌ Error: {e}")
else:
    print("\n✅ All dependencies already installed! You're ready to go.")

# %% [markdown]
# ---
#
# ## 📚 Workshop Notebooks
#
# ### Workshop 1: Foundations of AI — NLP to LLMs
# *Understanding how AI learns language*
#
# | Notebook | Topic |
# |----------|-------|
# | `1_AI_learning.ipynb` | How AI models learn from data |
# | `2_AI_modeling.ipynb` | The complete AI training loop |
# | `3_encodings_embeddings.ipynb` | How text becomes numbers |
# | `4_attention.ipynb` | The attention mechanism |
# | `5_LLM_modeling.ipynb` | Building large language models |
#
# ### Workshop 2: Foundations of AI — Deep Learning & Computer Vision
# *Understanding how AI sees and creates*
#
# | Notebook | Topic |
# |----------|-------|
# | `6_Neurons_to_Networks.ipynb` | From neurons to neural networks |
# | `7_how_AI_sees.ipynb` | CNNs and computer vision |
# | `8_how_AI_captures_time.ipynb` | LSTMs and sequential memory |
# | `9_how_AI_generates_images.ipynb` | Diffusion models and image generation |
